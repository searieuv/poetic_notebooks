# %%
import random

spaces = False

# %%
letter_shifts = [
    ('a', 'e'),
    ('A', 'E'),
    ('e', 'i'),
    ('E', 'I'),
    ('i', 'o'),
    ('I', 'O'),
    ('o', 'u'),
    ('O', 'U'),
    ('u', 'y'),
    ('U', 'Y'),
    ('y', 'yy'),
    ('Y', 'YY')
]

# %%
#Copyright Iron Butterfly, 1968 or so. Not mine.

phrase = '''

In a gadda da vida, honey
Don't you know that I'm lovin' you
In a gadda da vida, baby
Don't you know that I'll always be true

Oh, won't you come with me
And take my hand
Oh, won't you come with me
And walk this land
Please take my hand

In a gadda da vida, honey
Don't you know that I'm lovin' you
In a gadda da vida, baby
Don't you know that I'll always be true

Oh, won't you come with me
And take my hand
Oh, won't you come with me
And walk this land
Please take my hand

'''

phrase_orig = phrase

# %%
phrase_alt = list(phrase)


for i, letter in enumerate(phrase_alt):
    for x in letter_shifts:
        if letter == x[0]:
            phrase_alt[i] = x[1]

# %%
if spaces == False:

    phrase_alt_copy = phrase_alt[:]

    for letter in phrase_alt:
        if letter == ' ':
            phrase_alt_copy.remove(' ')

    phrase_alt = phrase_alt_copy

# %%
phrase = "".join(phrase_alt)
phrase = phrase.replace('\n\n', '\n').upper()
print(phrase)
# Out:
# ONEGEDDEDEVODE,HUNIYY
# DUN'TYYUYKNUWTHETO'MLUVON'YYUY
# ONEGEDDEDEVODE,BEBYY
# DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI
# UH,WUN'TYYUYCUMIWOTHMI
# ENDTEKIMYYHEND
# UH,WUN'TYYUYCUMIWOTHMI
# ENDWELKTHOSLEND
# PLIESITEKIMYYHEND
# ONEGEDDEDEVODE,HUNIYY
# DUN'TYYUYKNUWTHETO'MLUVON'YYUY
# ONEGEDDEDEVODE,BEBYY
# DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI
# UH,WUN'TYYUYCUMIWOTHMI
# ENDTEKIMYYHEND
# UH,WUN'TYYUYCUMIWOTHMI
# ENDWELKTHOSLEND
# PLIESITEKIMYYHEND

# %%
phrase_alt = phrase.split('\n')

phrase_alt_copy = phrase_alt[:]
for el in phrase_alt:
    if el == '':
        phrase_alt_copy.remove('')
        
phrase_alt = phrase_alt_copy

phrase_alt.sort(key=len)

phrase = "\n".join(phrase_alt)
print(phrase)
# Out:
# ENDTEKIMYYHEND
# ENDTEKIMYYHEND
# ENDWELKTHOSLEND
# ENDWELKTHOSLEND
# PLIESITEKIMYYHEND
# PLIESITEKIMYYHEND
# ONEGEDDEDEVODE,BEBYY
# ONEGEDDEDEVODE,BEBYY
# ONEGEDDEDEVODE,HUNIYY
# ONEGEDDEDEVODE,HUNIYY
# UH,WUN'TYYUYCUMIWOTHMI
# UH,WUN'TYYUYCUMIWOTHMI
# UH,WUN'TYYUYCUMIWOTHMI
# UH,WUN'TYYUYCUMIWOTHMI
# DUN'TYYUYKNUWTHETO'MLUVON'YYUY
# DUN'TYYUYKNUWTHETO'MLUVON'YYUY
# DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI
# DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI

# %%
print(phrase_alt)
# Out:
# ['ENDTEKIMYYHEND', 'ENDTEKIMYYHEND', 'ENDWELKTHOSLEND', 'ENDWELKTHOSLEND', 'PLIESITEKIMYYHEND', 'PLIESITEKIMYYHEND', 'ONEGEDDEDEVODE,BEBYY', 'ONEGEDDEDEVODE,BEBYY', 'ONEGEDDEDEVODE,HUNIYY', 'ONEGEDDEDEVODE,HUNIYY', "UH,WUN'TYYUYCUMIWOTHMI", "UH,WUN'TYYUYCUMIWOTHMI", "UH,WUN'TYYUYCUMIWOTHMI", "UH,WUN'TYYUYCUMIWOTHMI", "DUN'TYYUYKNUWTHETO'MLUVON'YYUY", "DUN'TYYUYKNUWTHETO'MLUVON'YYUY", "DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI", "DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI"]

# %%
for i in range(20):
    print(random.choice(phrase_alt))
# Out:
# PLIESITEKIMYYHEND
# ENDWELKTHOSLEND
# ENDTEKIMYYHEND
# UH,WUN'TYYUYCUMIWOTHMI
# ONEGEDDEDEVODE,BEBYY
# PLIESITEKIMYYHEND
# DUN'TYYUYKNUWTHETO'MLUVON'YYUY
# ENDTEKIMYYHEND
# ONEGEDDEDEVODE,HUNIYY
# ENDWELKTHOSLEND
# ENDTEKIMYYHEND
# ONEGEDDEDEVODE,BEBYY
# ENDTEKIMYYHEND
# DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI
# DUN'TYYUYKNUWTHETO'MLUVON'YYUY
# DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI
# DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI
# DUN'TYYUYKNUWTHETO'MLUVON'YYUY
# PLIESITEKIMYYHEND
# ENDTEKIMYYHEND

# %%
phrase_new = phrase_orig.replace('\n', ' ')

print(phrase_new)
# Out:
#   In a gadda da vida, honey Don't you know that I'm lovin' you In a gadda da vida, baby Don't you know that I'll always be true  Oh, won't you come with me And take my hand Oh, won't you come with me And walk this land Please take my hand  In a gadda da vida, honey Don't you know that I'm lovin' you In a gadda da vida, baby Don't you know that I'll always be true  Oh, won't you come with me And take my hand Oh, won't you come with me And walk this land Please take my hand

# %%
phrase_alt_orig = phrase_new.split()
print(phrase_alt_orig)
# Out:
# ['In', 'a', 'gadda', 'da', 'vida,', 'honey', "Don't", 'you', 'know', 'that', "I'm", "lovin'", 'you', 'In', 'a', 'gadda', 'da', 'vida,', 'baby', "Don't", 'you', 'know', 'that', "I'll", 'always', 'be', 'true', 'Oh,', "won't", 'you', 'come', 'with', 'me', 'And', 'take', 'my', 'hand', 'Oh,', "won't", 'you', 'come', 'with', 'me', 'And', 'walk', 'this', 'land', 'Please', 'take', 'my', 'hand', 'In', 'a', 'gadda', 'da', 'vida,', 'honey', "Don't", 'you', 'know', 'that', "I'm", "lovin'", 'you', 'In', 'a', 'gadda', 'da', 'vida,', 'baby', "Don't", 'you', 'know', 'that', "I'll", 'always', 'be', 'true', 'Oh,', "won't", 'you', 'come', 'with', 'me', 'And', 'take', 'my', 'hand', 'Oh,', "won't", 'you', 'come', 'with', 'me', 'And', 'walk', 'this', 'land', 'Please', 'take', 'my', 'hand']

# %%
for k in range(10):
    for i in range(20):
        snippets = []
        for j in range(2):
            snippet_length = random.randrange(1, 6)
            start_position = random.randrange(len(phrase_alt_orig))
            end_position = min([start_position + snippet_length, len(phrase_alt_orig)])
            snippet = " ".join(phrase_alt_orig[start_position:end_position])
            snippets.append(snippet)
        snippets.append(random.choice(phrase_alt))

        random.shuffle(snippets)
        print(" ".join(snippets))
    print()
# Out:
# you come with me UH,WUN'TYYUYCUMIWOTHMI this land Please
# I'm lovin' land Please take PLIESITEKIMYYHEND
# that won't you come with UH,WUN'TYYUYCUMIWOTHMI
# ENDTEKIMYYHEND Don't you you
# DUN'TYYUYKNUWTHETO'MLUVON'YYUY honey Don't you won't you come with
# In DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI you come with me And
# with me always be true Oh, UH,WUN'TYYUYCUMIWOTHMI
# that Oh, won't you come with UH,WUN'TYYUYCUMIWOTHMI
# ENDWELKTHOSLEND with me And take know that
# UH,WUN'TYYUYCUMIWOTHMI know that that I'll always be
# ENDTEKIMYYHEND be In a gadda da vida,
# UH,WUN'TYYUYCUMIWOTHMI Oh, won't In a
# Oh, DUN'TYYUYKNUWTHETO'MLUVON'YYUY hand
# DUN'TYYUYKNUWTHETO'MLUVON'YYUY hand this
# I'll always be true this land DUN'TYYUYKNUWTHETO'MLUVON'YYUY
# ENDWELKTHOSLEND won't you come with me you know
# UH,WUN'TYYUYCUMIWOTHMI a gadda da lovin' you In
# that I'll always you In ONEGEDDEDEVODE,BEBYY
# vida, honey Don't you ENDTEKIMYYHEND I'm lovin'
# lovin' you In a DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI take my hand
#
# UH,WUN'TYYUYCUMIWOTHMI my hand Oh, won't you my hand
# da vida, gadda da vida, honey Don't ENDWELKTHOSLEND
# my hand In a gadda you ENDTEKIMYYHEND
# you know that In DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI
# gadda da vida, ENDTEKIMYYHEND da vida, baby Don't you
# you come with me And gadda da ONEGEDDEDEVODE,BEBYY
# come with me gadda da vida, DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI
# hand PLIESITEKIMYYHEND And walk
# walk this land Please take DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI know
# PLIESITEKIMYYHEND you always be true Oh,
# you know that ENDTEKIMYYHEND da
# UH,WUN'TYYUYCUMIWOTHMI you know that And take my hand
# ENDTEKIMYYHEND me And take won't you come
# me And take my I'm lovin' UH,WUN'TYYUYCUMIWOTHMI
# ONEGEDDEDEVODE,HUNIYY a gadda da vida, with me
# with me And know UH,WUN'TYYUYCUMIWOTHMI
# baby DUN'TYYUYKNUWTHETO'MLUVON'YYUY me
# ENDTEKIMYYHEND you honey Don't you
# ENDWELKTHOSLEND hand Oh, my
# ONEGEDDEDEVODE,HUNIYY be true Oh, gadda da vida, honey
#
# DUN'TYYUYKNUWTHETO'MLUVON'YYUY you know that that I'm lovin' you In
# a gadda da vida, my hand Oh, DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI
# you come with me And honey ENDWELKTHOSLEND
# walk this land Please take a ONEGEDDEDEVODE,HUNIYY
# PLIESITEKIMYYHEND won't you my hand In a
# with me And walk this DUN'TYYUYKNUWTHETO'MLUVON'YYUY In a gadda
# be true Oh, land Please DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI
# that I'll always be UH,WUN'TYYUYCUMIWOTHMI that I'll always be
# with me And walk this won't UH,WUN'TYYUYCUMIWOTHMI
# with me da vida, ENDWELKTHOSLEND
# ENDTEKIMYYHEND that I'm lovin' vida, baby Don't
# you know that I'll always always be true Oh, won't UH,WUN'TYYUYCUMIWOTHMI
# DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI Don't you know that know that I'm lovin'
# ONEGEDDEDEVODE,HUNIYY be true this
# DUN'TYYUYKNUWTHETO'MLUVON'YYUY know that a
# ONEGEDDEDEVODE,HUNIYY won't you come with me with me And walk
# PLIESITEKIMYYHEND land Please take my take
# DUN'TYYUYKNUWTHETO'MLUVON'YYUY be Oh,
# a gadda DUN'TYYUYKNUWTHETO'MLUVON'YYUY come with
# In a gadda da ONEGEDDEDEVODE,BEBYY vida,
#
# ONEGEDDEDEVODE,BEBYY a gadda da won't you come
# And walk this land DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI know that I'll
# ENDTEKIMYYHEND my hand In vida, honey Don't
# DUN'TYYUYKNUWTHETO'MLUVON'YYUY honey And walk this
# DUN'TYYUYKNUWTHETO'MLUVON'YYUY I'm lovin' come
# lovin' you In a gadda DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI baby Don't you know
# UH,WUN'TYYUYCUMIWOTHMI my hand In a gadda you come with
# DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI a gadda always be true
# And take my hand ENDWELKTHOSLEND a gadda da
# my hand In DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI take my hand
# you come with UH,WUN'TYYUYCUMIWOTHMI And take my hand
# da vida, ONEGEDDEDEVODE,HUNIYY land
# walk hand Oh, won't PLIESITEKIMYYHEND
# a DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI take my hand
# me And walk take UH,WUN'TYYUYCUMIWOTHMI
# always be ENDWELKTHOSLEND vida, honey Don't you know
# In a gadda da vida, DUN'TYYUYKNUWTHETO'MLUVON'YYUY honey Don't you
# PLIESITEKIMYYHEND you come with me And you come
# ENDWELKTHOSLEND won't come with
# you me And take my UH,WUN'TYYUYCUMIWOTHMI
#
# ENDTEKIMYYHEND take my hand always
# take my hand Oh, ONEGEDDEDEVODE,BEBYY walk this land Please
# won't you come with me DUN'TYYUYKNUWTHETO'MLUVON'YYUY you In a gadda
# ONEGEDDEDEVODE,BEBYY this land hand Oh, won't
# da vida, honey Don't you my hand DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI
# know that DUN'TYYUYKNUWTHETO'MLUVON'YYUY that
# walk this land Please take UH,WUN'TYYUYCUMIWOTHMI that I'll
# won't you a gadda da vida, UH,WUN'TYYUYCUMIWOTHMI
# UH,WUN'TYYUYCUMIWOTHMI Oh, take my hand Oh, won't
# lovin' you In a gadda with me ONEGEDDEDEVODE,HUNIYY
# take my hand In PLIESITEKIMYYHEND my hand
# you know that I'll always Oh, won't you come with DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI
# ONEGEDDEDEVODE,HUNIYY Oh, won't you come with Oh, won't
# you come with UH,WUN'TYYUYCUMIWOTHMI a gadda
# me And walk this land ONEGEDDEDEVODE,BEBYY you
# ENDWELKTHOSLEND Oh, won't you come with me And
# that I'm lovin' you ONEGEDDEDEVODE,HUNIYY hand In
# this land UH,WUN'TYYUYCUMIWOTHMI vida, baby
# ENDWELKTHOSLEND me And take my won't you come with me
# ENDWELKTHOSLEND land And walk this
# DUN'TYYUYKNUWTHETO'MLUVON'YYUY you In a gadda da my
# DUN'TYYUYKNUWTHETO'MLUVON'YYUY you know that with me
# vida, honey Don't ENDTEKIMYYHEND In a
# ONEGEDDEDEVODE,BEBYY And Oh, won't

# %%
in_the_garden = '''
I come to the garden alone
While the dew is still on the roses
And the voice I hear, falling on my ear,
The Son of God discloses
Refrain: And He walks with me, and He talks with me,
And He tells me I am His own,
And the joy we share as we tarry there,
None other has ever known
He speaks, and the sound of His voice
Is so sweet the birds hush their singing
And the melody that He gave to me
Within my heart is ringing
I'd stay in the garden with Him
Tho' the night around me be falling
But He bids me go; thro' the voice of woe,
His voice to me is calling
'''

in_the_garden = in_the_garden.replace('\n', ' ')

print(in_the_garden)
# Out:
#  I come to the garden alone While the dew is still on the roses And the voice I hear, falling on my ear, The Son of God discloses Refrain: And He walks with me, and He talks with me, And He tells me I am His own, And the joy we share as we tarry there, None other has ever known He speaks, and the sound of His voice Is so sweet the birds hush their singing And the melody that He gave to me Within my heart is ringing I'd stay in the garden with Him Tho' the night around me be falling But He bids me go; thro' the voice of woe, His voice to me is calling

# %%
in_the_garden_list = in_the_garden.split()

print(in_the_garden_list)
# Out:
# ['I', 'come', 'to', 'the', 'garden', 'alone', 'While', 'the', 'dew', 'is', 'still', 'on', 'the', 'roses', 'And', 'the', 'voice', 'I', 'hear,', 'falling', 'on', 'my', 'ear,', 'The', 'Son', 'of', 'God', 'discloses', 'Refrain:', 'And', 'He', 'walks', 'with', 'me,', 'and', 'He', 'talks', 'with', 'me,', 'And', 'He', 'tells', 'me', 'I', 'am', 'His', 'own,', 'And', 'the', 'joy', 'we', 'share', 'as', 'we', 'tarry', 'there,', 'None', 'other', 'has', 'ever', 'known', 'He', 'speaks,', 'and', 'the', 'sound', 'of', 'His', 'voice', 'Is', 'so', 'sweet', 'the', 'birds', 'hush', 'their', 'singing', 'And', 'the', 'melody', 'that', 'He', 'gave', 'to', 'me', 'Within', 'my', 'heart', 'is', 'ringing', "I'd", 'stay', 'in', 'the', 'garden', 'with', 'Him', "Tho'", 'the', 'night', 'around', 'me', 'be', 'falling', 'But', 'He', 'bids', 'me', 'go;', "thro'", 'the', 'voice', 'of', 'woe,', 'His', 'voice', 'to', 'me', 'is', 'calling']

# %%
saved_poem_lines = []

all_songs = phrase_alt_orig + in_the_garden_list

for k in range(10):
    for i in range(21):
        snippets = []
        for j in range(2):
            snippet_length = random.randrange(1, 6)
            start_position = random.randrange(len(all_songs))
            end_position = min([start_position + snippet_length, len(all_songs)])
            snippet = " ".join(all_songs[start_position:end_position])
            snippets.append(snippet)
            
        snippets.append(random.choice(phrase_alt))

        random.shuffle(snippets)
        if i % 3 == 0:
            print(" ".join(snippets))
        elif i % 3 == 1:
            print("     ", " ".join(snippets), sep='')
        else:
            print("          ", " ".join(snippets), sep='')
            
        saved_poem_lines.append("".join(snippets))
        
        
    print()
# Out:
# take my hand ENDTEKIMYYHEND While the dew
#      DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI woe, His voice to of woe, His voice
#           this DUN'TYYUYKNUWTHETO'MLUVON'YYUY None other has
# UH,WUN'TYYUYCUMIWOTHMI you In a gadda da falling on my
#      to me, And He tells UH,WUN'TYYUYCUMIWOTHMI
#           me And walk this land ENDTEKIMYYHEND And He walks with me,
# to And walk this land DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI
#      you know DUN'TYYUYKNUWTHETO'MLUVON'YYUY go; thro' the voice of
#           Son of God ENDWELKTHOSLEND with me
# PLIESITEKIMYYHEND always be true ever
#      In a gadda know that ONEGEDDEDEVODE,HUNIYY
#           UH,WUN'TYYUYCUMIWOTHMI that I'll always the melody that He gave
# in the garden with Him PLIESITEKIMYYHEND to the
#      ENDTEKIMYYHEND take my hand take my hand Oh, won't
#           heart ENDTEKIMYYHEND am His own,
# DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI me roses And the
#      me be falling But ONEGEDDEDEVODE,HUNIYY baby Don't
#           to ENDWELKTHOSLEND Oh, won't you come
# that I'm lovin' you In with me ENDTEKIMYYHEND
#      PLIESITEKIMYYHEND always be true Oh, won't woe,
#           go; thro' the UH,WUN'TYYUYCUMIWOTHMI be falling
#
# of His voice Is UH,WUN'TYYUYCUMIWOTHMI woe, His voice
#      hand In a ONEGEDDEDEVODE,BEBYY to
#           you come with me me, ONEGEDDEDEVODE,BEBYY
# ONEGEDDEDEVODE,BEBYY walk this land Please take And
#      of God discloses Refrain: And ENDWELKTHOSLEND you In a gadda da
#           ENDTEKIMYYHEND I'm lovin' you walks with me, and He
# discloses voice of UH,WUN'TYYUYCUMIWOTHMI
#      I come UH,WUN'TYYUYCUMIWOTHMI with me, and He
#           UH,WUN'TYYUYCUMIWOTHMI In a gadda da vida, He walks with me,
# heart UH,WUN'TYYUYCUMIWOTHMI dew is still
#      In ONEGEDDEDEVODE,BEBYY be true
#           ENDWELKTHOSLEND me And take my hand of woe, His voice
# won't you come Oh, won't UH,WUN'TYYUYCUMIWOTHMI
#      I'd stay in the as we tarry there, None UH,WUN'TYYUYCUMIWOTHMI
#           He bids me is calling DUN'TYYUYKNUWTHETO'MLUVON'YYUY
# I'll always be UH,WUN'TYYUYCUMIWOTHMI gadda da
#      UH,WUN'TYYUYCUMIWOTHMI the night around me won't you come
#           And DUN'TYYUYKNUWTHETO'MLUVON'YYUY that I'm lovin'
# take my me, PLIESITEKIMYYHEND
#      melody that He gave to know that I'm lovin' DUN'TYYUYKNUWTHETO'MLUVON'YYUY
#           true Oh, won't you tarry ONEGEDDEDEVODE,BEBYY
#
# a gadda da vida, baby ENDWELKTHOSLEND that I'll always be true
#      lovin' you In the melody ENDTEKIMYYHEND
#           PLIESITEKIMYYHEND the voice with me And
# Oh, won't you my DUN'TYYUYKNUWTHETO'MLUVON'YYUY
#      this land my heart is ringing ONEGEDDEDEVODE,HUNIYY
#           ONEGEDDEDEVODE,HUNIYY the voice I hear, I hear, falling on my
# gadda da vida, baby Don't ONEGEDDEDEVODE,HUNIYY you In a gadda
#      is calling of God discloses DUN'TYYUYKNUWTHETO'MLUVON'YYUY
#           I you come with UH,WUN'TYYUYCUMIWOTHMI
# PLIESITEKIMYYHEND falling always be true Oh,
#      DUN'TYYUYKNUWTHETO'MLUVON'YYUY my hand I come around me be falling
#           ONEGEDDEDEVODE,BEBYY on the da
# DUN'TYYUYKNUWTHETO'LLELWEYYSBITRYI falling on my ear, The go;
#      ONEGEDDEDEVODE,HUNIYY you know that I'm know that I'll always be
#           my hand Oh, won't you their singing And PLIESITEKIMYYHEND
# ENDTEKIMYYHEND thro' the and He
#      DUN'TYYUYKNUWTHETO'MLUVON'YYUY alone While the da vida, baby
#           a gadda da vida, baby Him Tho' ENDWELKTHOSLEND
# PLIESITEKIMYYHEND singing And the melody that you
#      In a me And ENDWELKTHOSLEND
#           ear, ENDTEKIMYYHEND take my hand In a

# %%
#new_small_poem = []

for j in range(20):
    for i in range(5):
        temp_line = random.choice(saved_poem_lines)
        start_position = random.randrange(len(temp_line) - 10)
        end_position = start_position + 10
        print(temp_line[start_position:end_position])
    print()
# Out:
# YKNUWTHETO
# ew is stil
# OTHMIthe n
# ne While t
# keother ha
#
# you come w
# know that
# e Oh, won'
# ain:thro'
# n't you kn
#
# ITEKIMYYHE
# asUH,WUN'T
# OTHMIIn a
# be trueeve
# HOSLENDgav
#
# n't you kn
# dENDWELKTH
# MIWOTHMIOh
# rdenUH,WUN
# UYKNUWTHET
#
# YHENDwith
#  Andstill
# DEVODE,BEB
# LKTHOSLEND
# IMYYHENDal
#
# t you know
#  knownof G
# MLUVON'YYU
#  I'll alwa
# 'TYYUYCUMI
#
# YHENDalway
# TO'LLELWEY
# ELKTHOSLEN
# know thatO
# 'LLELWEYYS
#
# TheONEGEDD
# N'YYUYgave
# VODE,BEBYY
# so sweetUH
# YYother ha
#
# CUMIWOTHMI
# ENDWELKTHO
# H,WUN'TYYU
# am HisENDT
# WTHETO'MLU
#
# k thisPLIE
# now that I
# oneUH,WUN'
# UMIWOTHMIH
# rdenweENDW
#
# VON'YYUYjo
# g onONEGED
# a vida, ba
# da, honey
# on the ros
#
# HMIda vida
# aENDTEKIMY
# vida, baby
# that He ga
# He talkswo
#
# ake my han
# ONEGEDDEDE
# ENDTEKIMYY
# And He tel
# EYYSBITRYI
#
# O'MLUVON'Y
# to the gar
# UN'TYYUYKN
# lways be t
# n a gadda
#
# ONEGEDDEDE
# YHENDWhile
# ou come wi
# a vida, ho
# at I'm lov
#
# HETO'LLELW
# EKIMYYHEND
# WOTHMImy h
#  be true O
# UYKNUWTHET
#
# KNUWTHETO'
# IMYYHENDAn
# EVODE,BEBY
# wn Heof wo
# Oh,voice I
#
# YYUYKNUWTH
# LLELWEYYSB
# ENDAndme i
# , honeyEND
#  theENDWEL
#
# UWTHETO'LL
# Him Tho'bi
# the voice
# YHENDyou c
# theENDWELK
#
# m Tho' the
# 'TYYUYCUMI
# toONEGEDDE
# e AndENDWE
# YUYIn a ga

# %%
for j in range(5):
    for i in range(5):
        line_of_lines = []
        for k in range(5):
            temp_line = random.choice(saved_poem_lines)
            start_position = random.randrange(len(temp_line) - 10)
            end_position = start_position + 10
            line_of_lines.append(temp_line[start_position:end_position].replace(' ', ':'))
            if k < 4:
                line_of_lines.append('   ')
        print("".join(line_of_lines))
    print()
# Out:
# esme,:And:   me:Andhone   :take:my:h   ouDUN'TYYU   e:talkswon
# EDEVODE,HU   ke:myme,PL   ITEKIMYYHE   th:Him:Tho   O'LLELWEYY
# ever:known   :dada:vida   y:wePLIESI   the:sound:   H,WUN'TYYU
# UH,WUN'TYY   e:be:falli   nd:Oh,othe   ndUH,WUN'T   UH,WUN'TYY
# EKIMYYHEND   YYUYKNUWTH   HOSLENDgav   eir:singin   ,ENDTEKIMY
#
# MYYHENDwit   o:the:gard   heENDWELKT   HENDAnd:He   :own,:And:
# know:that:   YYbe:falli   y:hand:Oh,   own:Heof:w   e:theisEND
# His:own,:A   TYYUYCUMIW   H,WUN'TYYU   EYYSBITRYI   a:gadda:da
# 'TYYUYCUMI   know:that:   IMYYHENDvi   ETO'MLUVON   with:me:An
# lks:with:m   heartUH,WU   :the:garde   TYYUYCUMIW   DEVODE,HUN
#
# e:true:Oh,   eartUH,WUN   n::AndENDW   h,beENDTEK   MIWOTHMIas
# wn,:And:th   ndDUN'TYYU   TEKIMYYHEN   TYYUYKNUWT   O'MLUVON'Y
# falling:on   eONEGEDDED   ENDWhile:t   EYYSBITRYI   WOTHMIgadd
# YYUYKNUWTH   PLIESITEKI   is:own,:An   ESITEKIMYY   ELKTHOSLEN
# take:my:ha   et:the:bir   ENDgavegad   WUN'TYYUYC   ODE,BEBYYW
#
# UN'TYYUYCU   e:with:meO   YYUYKNUWTH   IMYYHENDth   allingalwa
# ll:always:   share:as:w   YHENDHe:wa   TYYUYCUMIW   TYYUYCUMIW
# YUYCUMIWOT   HUNIYYme:W   N'TYYUYCUM   KTHOSLENDm   with:me:An
# DEVODE,HUN   ENDalways:   WUN'TYYUYC   ever:known   e:And:take
# lls:meONEG   YCUMIWOTHM   EDEVODE,BE   eDUN'TYYUY   always:be:
#
# TRYImerose   own,:And:t   EGEDDEDEVO   oENDWELKTH   DE,HUNIYYy
# NDso:sweet   ONEGEDDEDE   While:the:   E,HUNIYYI'   TEKIMYYHEN
# my:hand:Oh   DEVODE,HUN   HETO'LLELW   UMIWOTHMIt   ENDTEKIMYY
# 't:you:kno   loses:Refr   HENDyou:co   ada:vida,O   N'TYYUYKNU
# gDUN'TYYUY   DE,HUNIYYy   lways:be:t   :hand:Oh,d   LIESITEKIM
